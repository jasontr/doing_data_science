# %%
import pandas as pd

# %%
data = pd.read_excel('./dds_ch2_rollingsales/rollingsales_brooklyn.xls')
data
# Out:
#       Brooklyn Rolling Sales File.  All Sales From August 2012 - August 2013.   \
# 0      Sales File as of 08/30/2013  Coop Sales Files ...
# 1      Neighborhood Name 09/06/13, Descriptive Data i...
# 2      Building Class Category is based on Building C...
# 3                                                BOROUGH
# 4                                                      3
# 5                                                      3
# 6                                                      3
# 7                                                      3
# 8                                                      3
# 9                                                      3
# 10                                                     3
# 11                                                     3
# 12                                                     3
# 13                                                     3
# 14                                                     3
# ...

# %%
# Out:
# <bound method NDFrame.describe of       Brooklyn Rolling Sales File.  All Sales From August 2012 - August 2013.   \
# 0      Sales File as of 08/30/2013  Coop Sales Files ...
# 1      Neighborhood Name 09/06/13, Descriptive Data i...
# 2      Building Class Category is based on Building C...
# 3                                                BOROUGH
# 4                                                      3
# 5                                                      3
# 6                                                      3
# 7                                                      3
# 8                                                      3
# 9                                                      3
# 10                                                     3
# 11                                                     3
# 12                                                     3
# 13                                                     3
# ...
